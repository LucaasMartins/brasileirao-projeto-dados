# %%
# Média de público por estado
df.groupby('estado')['publico'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title('Média de público por estado')
plt.ylabel('Média de público')
plt.show()

# %%
# Criar coluna de resultado
df['resultado'] = 'empate'
df.loc[df['gols_mandante'] > df['gols_visitante'], 'resultado'] = 'mandante'
df.loc[df['gols_mandante'] < df['gols_visitante'], 'resultado'] = 'visitante'

# Contagem de resultados
resultado_counts = df['resultado'].value_counts()
print(resultado_counts)
# Out:
# resultado
# mandante     5
# visitante    5
# empate       2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Média de gols por ano
df.groupby('ano')[['gols_mandante', 'gols_visitante']].mean().plot(kind='bar')
plt.title('Média de Gols por Ano')
plt.ylabel('Média de Gols')
plt.show()

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
df['mandante'].unique()
# Out:
# array(['Palmeiras', 'Flamengo', 'Corinthians', 'São Paulo', 'Atlético-MG',
#        'Grêmio', 'Internacional', 'Santos', 'Botafogo', 'Fortaleza',
#        'Bahia', 'Cruzeiro'], dtype=object)

# %%
df.describe()
# Out:
#                ano     rodada  gols_mandante  gols_visitante       publico
# count    12.000000  12.000000      12.000000       12.000000     12.000000
# mean   2021.500000   1.500000       1.750000        1.416667  36166.666667
# std       1.783765   0.522233       1.215431        0.900337   9561.602503
# min    2019.000000   1.000000       0.000000        0.000000  25000.000000
# 25%    2020.000000   1.000000       1.000000        1.000000  29750.000000
# 50%    2021.500000   1.500000       2.000000        1.500000  34500.000000
# 75%    2023.000000   2.000000       2.250000        2.000000  39000.000000
# max    2024.000000   2.000000       4.000000        3.000000  60000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ano             12 non-null     int64
#  1   rodada          12 non-null     int64
#  2   data            12 non-null     object
#  3   mandante        12 non-null     object
#  4   visitante       12 non-null     object
#  5   gols_mandante   12 non-null     int64
#  6   gols_visitante  12 non-null     int64
#  7   estadio         12 non-null     object
#  8   cidade          12 non-null     object
#  9   estado          12 non-null     object
#  10  publico         12 non-null     int64
# dtypes: int64(5), object(6)
# memory usage: 1.2+ KB

# %%
import pandas as pd

df = pd.read_csv('../data/raw/brasileirao_2019_2024.csv')
df.head()
# Out:
#     ano  rodada        data     mandante  visitante  gols_mandante  \
# 0  2019       1  2019-04-28    Palmeiras        CSA              4
# 1  2019       2  2019-05-05     Flamengo   Cruzeiro              3
# 2  2020       1  2020-08-09  Corinthians      Bahia              2
# 3  2020       2  2020-08-12    São Paulo   Botafogo              1
# 4  2021       1  2021-05-29  Atlético-MG  Fortaleza              2
#
#    gols_visitante            estadio          cidade estado  publico
# 0               0     Allianz Parque       São Paulo     SP    32000
# 1               1           Maracanã  Rio de Janeiro     RJ    60000
# 2               2  Neo Química Arena       São Paulo     SP    38000
# 3               2            Morumbi       São Paulo     SP    42000
# 4               0           Mineirão  Belo Horizonte     MG    45000
